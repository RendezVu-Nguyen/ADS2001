# %% [markdown]
# Load data

# %%
import pandas as pd
df = pd.read_csv("adjprice.csv")
df
# Out:
#           Date  0111145D US Equity  0202445Q US Equity  0203524D US Equity  \
# 0     19930907             13.2719             13.6829              8.4429
# 1     19930908             13.3263             13.5315              8.2147
# 2     19930909             13.7070             13.3800              8.7852
# 3     19930910             13.3807             13.4810              9.4127
# 4     19930911             13.3807             13.4810              9.4127
# ...        ...                 ...                 ...                 ...
# 9454  20190727                 NaN                 NaN                 NaN
# 9455  20190728                 NaN                 NaN                 NaN
# 9456  20190729                 NaN                 NaN                 NaN
# 9457  20190730                 NaN                 NaN                 NaN
# 9458  20190731                 NaN                 NaN                 NaN
#
#       0226226D US Equity  0376152D US Equity  0440296D US Equity  \
# ...

# %% [markdown]
# Keep stocks with 90% coverage

# %%
coverage = df.notna().mean()
df = df.loc[:, coverage >= 0.9]
df
# Out:
#           Date  1436513D US Equity  AA US Equity  AAPL US Equity  \
# 0     19930907              3.0147       13.6285          0.8044
# 1     19930908              2.9691       13.3718          0.8197
# 2     19930909              3.0278       13.4652          0.7967
# 3     19930910              3.0278       13.3952          0.8044
# 4     19930911              3.0278       13.3952          0.8044
# ...        ...                 ...           ...             ...
# 9454  20190727                 NaN       23.1300        207.7400
# 9455  20190728                 NaN       23.1300        207.7400
# 9456  20190729                 NaN       23.1200        209.6800
# 9457  20190730                 NaN       23.0400        208.7800
# 9458  20190731                 NaN       23.0400        208.7800
#
#       ABC US Equity  ABMD US Equity  ABT US Equity  ABX US Equity  \
# 0               NaN           3.750         3.2659        16.9898
# ...

# %% [markdown]
# Drop any rows with N/A values

# %%
df_clean = df.dropna()
df_clean
# Out:
#           Date  1436513D US Equity  AA US Equity  AAPL US Equity  \
# 904   19960228              3.9666       21.4810          0.8753
# 905   19960229              4.0085       22.3658          0.8674
# 906   19960301              3.9037       22.5133          0.8477
# 907   19960302              3.9037       22.5133          0.8477
# 908   19960303              3.9037       22.5133          0.8477
# ...        ...                 ...           ...             ...
# 8413  20160919             45.4500       20.9622        109.5665
# 8414  20160920             45.4500       21.1414        109.5569
# 8415  20160921             45.4500       21.6565        109.5376
# 8416  20160922             45.4500       21.9028        110.5698
# 8417  20160923             45.4500       21.8581        108.7272
#
#       ABC US Equity  ABMD US Equity  ABT US Equity  ABX US Equity  \
# 904          2.9793           6.063         5.4616        23.8016
# ...

# %% [markdown]
# Remove duplicated rows (weekends and public holidays) and non-publicly traded entities (numerical tickers)

# %%
df_cleaned = df_clean[~df_clean.iloc[:, 1:].duplicated()]
df_cleaned = df_cleaned.drop(df.columns[1], axis=1)
df_cleaned
# Out:
#           Date  AA US Equity  AAPL US Equity  ABC US Equity  ABMD US Equity  \
# 904   19960228       21.4810          0.8753         2.9793           6.063
# 905   19960229       22.3658          0.8674         2.9793           6.063
# 906   19960301       22.5133          0.8477         2.8766           6.438
# 909   19960304       22.8574          0.8280         2.9279           6.063
# 910   19960305       22.8082          0.8398         3.0050           6.063
# ...        ...           ...             ...            ...             ...
# 8413  20160919       20.9622        109.5665        80.0464         125.100
# 8414  20160920       21.1414        109.5569        78.9119         125.100
# 8415  20160921       21.6565        109.5376        79.8156         126.900
# 8416  20160922       21.9028        110.5698        80.3636         126.370
# 8417  20160923       21.8581        108.7272        80.1137         123.530
#
# ...

# %% [markdown]
# Get tickers

# %%
tickers = []
for col in df_cleaned.columns[2:]:
    tickers.append(col.split()[0])

ticker_df = pd.DataFrame({"Ticker": tickers})
ticker_df
# Out:
#     Ticker
# 0     AAPL
# 1      ABC
# 2     ABMD
# 3      ABT
# 4      ABX
# ..     ...
# 450    XOM
# 451   XRAY
# 452    XRX
# 453   YRCW
# 454   ZION
#
# [455 rows x 1 columns]

# %% [markdown]
# Load dataset containing tickers and their corresponding sectors

# %%
sectors = pd.read_csv("SP500.csv")
sector_df = sectors.rename(columns={"Symbol": "Ticker"})
sector_df
# Out:
#     Ticker                    Name                  Sector
# 0      MMM              3M Company             Industrials
# 1      AOS         A.O. Smith Corp             Industrials
# 2      ABT     Abbott Laboratories             Health Care
# 3     ABBV             AbbVie Inc.             Health Care
# 4      ACN           Accenture plc  Information Technology
# ..     ...                     ...                     ...
# 500    XYL              Xylem Inc.             Industrials
# 501    YUM         Yum! Brands Inc  Consumer Discretionary
# 502    ZBH  Zimmer Biomet Holdings             Health Care
# 503   ZION           Zions Bancorp              Financials
# 504    ZTS                  Zoetis             Health Care
#
# [505 rows x 3 columns]

# %% [markdown]
# Merge ticker-sector dataframe with tickers dataset

# %%
ticker_df = ticker_df.merge(sector_df, on="Ticker", how="left")
ticker_df
# Out:
#     Ticker                    Name                  Sector
# 0     AAPL              Apple Inc.  Information Technology
# 1      ABC  AmerisourceBergen Corp             Health Care
# 2     ABMD                     NaN                     NaN
# 3      ABT     Abbott Laboratories             Health Care
# 4      ABX                     NaN                     NaN
# ..     ...                     ...                     ...
# 450    XOM       Exxon Mobil Corp.                  Energy
# 451   XRAY         Dentsply Sirona             Health Care
# 452    XRX             Xerox Corp.  Information Technology
# 453   YRCW                     NaN                     NaN
# 454   ZION           Zions Bancorp              Financials
#
# [455 rows x 3 columns]

# %% [markdown]
# Number of unclassified tickers

# %%
ticker_df["Name"].isna().sum()
# Out:
# 113

# %% [markdown]
# Fill N/A sectors with "unknown"

# %%
ticker_df["Sector"] = ticker_df["Sector"].fillna("Unknown")
ticker_df
# Out:
#     Ticker                    Name                  Sector
# 0     AAPL              Apple Inc.  Information Technology
# 1      ABC  AmerisourceBergen Corp             Health Care
# 2     ABMD                     NaN                 Unknown
# 3      ABT     Abbott Laboratories             Health Care
# 4      ABX                     NaN                 Unknown
# ..     ...                     ...                     ...
# 450    XOM       Exxon Mobil Corp.                  Energy
# 451   XRAY         Dentsply Sirona             Health Care
# 452    XRX             Xerox Corp.  Information Technology
# 453   YRCW                     NaN                 Unknown
# 454   ZION           Zions Bancorp              Financials
#
# [455 rows x 3 columns]

# %% [markdown]
# Convert raw prices into returns

# %%
returns = df_cleaned.iloc[:, 1:].pct_change().dropna()
returns
# Out:
#       AA US Equity  AAPL US Equity  ABC US Equity  ABMD US Equity  \
# 905       0.041190       -0.009025       0.000000        0.000000
# 906       0.006595       -0.022712      -0.034471        0.061851
# 909       0.015284       -0.023239       0.017834       -0.058248
# 910      -0.002152        0.014251       0.026333        0.000000
# 911       0.006467       -0.016432       0.008552        0.000000
# ...            ...             ...            ...             ...
# 8413     -0.008476       -0.011661      -0.010106        0.001361
# 8414      0.008549       -0.000088      -0.014173        0.000000
# 8415      0.024365       -0.000176       0.011452        0.014388
# 8416      0.011373        0.009423       0.006866       -0.004177
# 8417     -0.002041       -0.016665      -0.003110       -0.022474
#
#       ABT US Equity  ABX US Equity  ADBE US Equity  ADI US Equity  \
# 905        0.009063      -0.008197       -0.007389      -0.031543
# ...

# %% [markdown]
# Apply static weight (relative) portfolio on every stock equally

# %%
import numpy as np
weights = np.ones(456) / 456
relative_portfolio = returns.dot(weights)
relative_portfolio
# Out:
# 905    -0.005494
# 906    -0.000159
# 909     0.011286
# 910     0.005694
# 911    -0.000954
#           ...
# 8413    0.002459
# 8414   -0.001991
# 8415    0.014854
# 8416    0.008599
# 8417   -0.006523
# Length: 5179, dtype: float64

# %% [markdown]
# Calculate mean return, volatility, variance, sharpe ratio, and VaR 95%

# %%
print("Mean Return (how much percentage did the portfolio gain per day on average):", relative_portfolio.mean())
print("Volatility (percentage that the portfolio fluctuates per day on average):", relative_portfolio.std())
print("Sharpe Ratio (return per unit of volatility):", relative_portfolio.mean()/relative_portfolio.std())
print("VaR 95% (maximum percentage of loss on 95% of days):", relative_portfolio.quantile(0.05))
# Out:
# Mean Return (how much percentage did the portfolio gain per day on average): 0.0006818827553907643
# Volatility (percentage that the portfolio fluctuates per day on average): 0.01292698053421302
# Sharpe Ratio (return per unit of volatility): 0.05274880344919438
# VaR 95% (maximum percentage of loss on 95% of days): -0.018801094035494705

# %% [markdown]
# import required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import minimize

# %% [markdown]
# equal weight benchmark

# %%
# Make dates align with returns rows
dates = pd.to_datetime(df_cleaned.loc[returns.index, "Date"].astype(str), format="%Y%m%d")

# Equal-weight benchmark
n = returns.shape[1]
equal_weights = np.ones(n) / n
equal_portfolio = returns.dot(equal_weights)
equal_cum = (1 + equal_portfolio).cumprod()

# %% [markdown]
# Compute the Full Covariance Matrix

# %%
cov_matrix = returns.cov()
cov_matrix
# Out:
#                 AA US Equity  AAPL US Equity  ABC US Equity  ABMD US Equity  \
# AA US Equity        0.000676        0.000183       0.000110        0.000211
# AAPL US Equity      0.000183        0.000855       0.000084        0.000183
# ABC US Equity       0.000110        0.000084       0.000440        0.000088
# ABMD US Equity      0.000211        0.000183       0.000088        0.001646
# ABT US Equity       0.000101        0.000073       0.000084        0.000096
# ...                      ...             ...            ...             ...
# XOM US Equity       0.000197        0.000101       0.000078        0.000111
# XRAY US Equity      0.000146        0.000092       0.000084        0.000127
# XRX US Equity       0.000240        0.000213       0.000104        0.000170
# YRCW US Equity      0.000302        0.000202       0.000105        0.000186
# ZION US Equity      0.000259        0.000173       0.000110        0.000235
#
# ...

# %% [markdown]
# Minimum Variance Portfolio Optimisation

# %%
# Minimalist model: Minimum Variance Portfolio

def portfolio_volatility(w):
    return np.sqrt(w.T @ cov_matrix @ w)

x0 = np.ones(n) / n
constraints = {"type": "eq", "fun": lambda w: np.sum(w) - 1}
bounds = [(0, 1)] * n

result = minimize(
    portfolio_volatility,
    x0,
    method="SLSQP",
    bounds=bounds,
    constraints=constraints
)

print("Optimization success:", result.success)
print("Message:", result.message)

min_var_weights = result.x
min_var_portfolio = returns.dot(min_var_weights)
min_var_cum = (1 + min_var_portfolio).cumprod()
# Out:
# Optimization success: True
# Message: Optimization terminated successfully

# %% [markdown]
# Portfolio Performance Metrics

# %%
# Summary metrics 
summary = pd.DataFrame({
    "Portfolio": ["Equal Weight", "Minimalist"],
    "Mean Daily Return": [equal_portfolio.mean(), min_var_portfolio.mean()],
    "Daily Volatility": [equal_portfolio.std(), min_var_portfolio.std()],
    "Sharpe Ratio": [
        equal_portfolio.mean() / equal_portfolio.std(),
        min_var_portfolio.mean() / min_var_portfolio.std()
    ],
    "VaR 95%": [
        equal_portfolio.quantile(0.05),
        min_var_portfolio.quantile(0.05)
    ]
})

summary
# Out:
#       Portfolio  Mean Daily Return  Daily Volatility  Sharpe Ratio   VaR 95%
# 0  Equal Weight           0.000682          0.012927      0.052749 -0.018801
# 1    Minimalist           0.000540          0.007814      0.069088 -0.011595

# %% [markdown]
# Top 10 holdings by weight

# %%
# Top 10 holdings by weight
top10 = pd.Series(min_var_weights, index=returns.columns)\
    .sort_values(ascending=False)\
    .head(10)

top10
# Out:
# GIS US Equity    0.123956
# SO US Equity     0.084950
# WEC US Equity    0.062792
# ED US Equity     0.061921
# SJM US Equity    0.045893
# ABX US Equity    0.045697
# BCR US Equity    0.045016
# MKC US Equity    0.042868
# MCD US Equity    0.042417
# GHC US Equity    0.041359
# dtype: float64

# %% [markdown]
# portfolio performance

# %%
# Figure 1: Minimalist cumulative performance with year axis
plt.figure(figsize=(10, 5))
plt.plot(dates, min_var_cum)
plt.title("Minimalist Portfolio Performance")
plt.xlabel("Year")
plt.ylabel("Portfolio Value")
plt.grid(True)
plt.savefig('fig1_performance.png',transparent=True)
plt.show()

# %% [markdown]
# benchmark comparison-Equal Weight vs Minimalist

# %%
# Figure 2: Equal-weight benchmark vs Minimalist
plt.figure(figsize=(10, 5))
plt.plot(dates, equal_cum, label="Equal Weight")
plt.plot(dates, min_var_cum, label="Minimalist")
plt.title("Cumulative Return: Equal Weight vs Minimalist")
plt.xlabel("Year")
plt.ylabel("Portfolio Value")
plt.legend()
plt.grid(True)
plt.savefig('fig2_comparison.png',transparent=True)
plt.show()

# %% [markdown]
# Portfolio Allocation

# %%
# Figure 3: Top 10 holdings
plt.figure(figsize=(10, 5))
top10.plot(kind="bar")
plt.title("Top 10 Holdings - Minimalist Portfolio")
plt.xlabel("Stock")
plt.ylabel("Weight")
plt.grid(axis="y")
plt.savefig("fig3_10_top.png", transparent=True, bbox_inches='tight')
plt.show()

# %% [markdown]
# Weight Distribution

# %%
# Figure 4: Weight distribution histogram
plt.figure(figsize=(10, 4))
plt.hist(min_var_weights, bins=50, edgecolor='black')
plt.title("Weight Distribution - Minimalist Portfolio")
plt.xlabel("Weight")
plt.ylabel("Number of Stocks")
plt.grid(axis='y')
plt.savefig('fig4_weight_distribution.png',transparent=True)
plt.show()

# %% [markdown]
# Efficient Frontier Analysis

# %%
# Figure 5: Efficient Frontier via Monte Carlo
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)
n = returns.shape[1]
mc_vols, mc_rets = [], []

for _ in range(5000):
    # Randomly select a subset of 10 to 50 stocks, rather than all 456.
    k = np.random.randint(10, 51)
    chosen = np.random.choice(n, k, replace=False)
    w_sub = np.random.dirichlet(np.ones(k))
    w = np.zeros(n)
    w[chosen] = w_sub

    mc_rets.append(returns.dot(w).mean())
    mc_vols.append(returns.dot(w).std())

plt.figure(figsize=(11, 7))

# 背景随机点云
plt.scatter(mc_vols, mc_rets, alpha=0.3, s=8, c='steelblue', label="Random Portfolios")

# Minimum Variance 点
plt.scatter(
    min_var_portfolio.std(),
    min_var_portfolio.mean(),
    color='red', s=150, zorder=5, label="Minimum Variance"
)

# Equal Weight 点
plt.scatter(
    equal_portfolio.std(),
    equal_portfolio.mean(),
    color='orange', s=150, zorder=5, label="Equal Weight"
)

# label
plt.annotate(
    "Minimum Variance",
    (min_var_portfolio.std(), min_var_portfolio.mean()),
    textcoords="offset points", xytext=(10, 6), fontsize=10, color='red'
)
plt.annotate(
    "Equal Weight",
    (equal_portfolio.std(), equal_portfolio.mean()),
    textcoords="offset points", xytext=(10, -12), fontsize=10, color='orange'
)

plt.xlabel("Daily Volatility (Risk)", fontsize=12)
plt.ylabel("Mean Daily Return", fontsize=12)
plt.title("Efficient Frontier - Monte Carlo Simulation (5000 Portfolios)", fontsize=13)
plt.legend(fontsize=10)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig('fig5_efficient_frontier.png', transparent=True, dpi=150)
plt.show()

# %%
# Final numbers for comparison graph

import numpy as np
import pandas as pd

# Daily portfolio returns
equal_portfolio = returns.dot(equal_weights)
min_var_portfolio = returns.dot(min_var_weights)

# Cumulative return curve
equal_cum = (1 + equal_portfolio).cumprod()
min_var_cum = (1 + min_var_portfolio).cumprod()

# Final cumulative return in %
equal_cumulative_return = (equal_cum.iloc[-1] - 1) * 100
min_var_cumulative_return = (min_var_cum.iloc[-1] - 1) * 100

# Daily standard deviation
equal_daily_std = equal_portfolio.std()
min_var_daily_std = min_var_portfolio.std()

# Annualized standard deviation / annualized risk
equal_annualized_std = equal_daily_std * np.sqrt(252)
min_var_annualized_std = min_var_daily_std * np.sqrt(252)

# Summary table
comparison_summary = pd.DataFrame({
    "Model": ["Equal Weight", "Minimum Variance"],
    "Cumulative Return (%)": [
        equal_cumulative_return,
        min_var_cumulative_return
    ],
    "Daily Std": [
        equal_daily_std,
        min_var_daily_std
    ],
    "Annualized Std": [
        equal_annualized_std,
        min_var_annualized_std
    ]
})

comparison_summary
# Out:
#               Model  Cumulative Return (%)  Daily Std  Annualized Std
# 0      Equal Weight            2113.764045   0.012927        0.205209
# 1  Minimum Variance            1297.508072   0.007814        0.124045
